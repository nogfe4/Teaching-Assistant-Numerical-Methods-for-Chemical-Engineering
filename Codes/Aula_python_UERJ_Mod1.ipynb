# %% [markdown]
# ## **Aula De Python para Engenharia Químca** 🧪🧬📊💻
# **Introdução à Engenharia Química II / Métodos Computacionais II**
#
# **Author: @nogfe4**
#
# ## **Módulo 1:**
#
#
# *   **`Introdução`**
# *   **`Variáveis`**
# *   **`Listas, Tuplas, Sets, Dicts`**
#
# ## **Módulo 2:**
#
# *   **`Funções`**
# *   **`Decisões, Laços, Iterações`**
# *   **`Introdução a Álgebra Linear com Python`**
#
# ## **Módulo 3:**
# *   **`Bibliotecas científicas`**
# *   **`Métodos Numéricos`**
#
# ## **Módulo 4:**
# *  **`Aplicações na Engenharia Química`**

# %% [markdown]
# # **AULA 01 - Módulo 1:**
#
# * Neste módulo, vamos dar os primeiros passos no Python, entendendo a linguagem e construindo a base necessária para resolver problemas de forma clara e estruturada.
#
# * Todo conhecimento destas aulas serão aplicados no trabalho.
#
# ### 🔹 Conteúdo da Aula:
# - **Introdução**
#   - O que é Python e onde é utilizado.
#   - Como executar códigos em Jupyter Notebook ou outro ambiente.
#   - Sintaxe básica e primeiros comandos.
#
# - **Variáveis**
#   - O que são variáveis e como armazenar informações na memória.
#   - Tipos de dados numéricos e texto (`int`, `float`, `str`).
#   - Convenções de nomes de variáveis no Python.
#   - Conversão de tipos (`int()`, `float()`, `str()`).
#
# - **Listas, Tuplas, Sets e Dicionários**
#   - Estruturas de dados fundamentais no Python.
#   - Como criar, acessar e modificar listas.
#   - Diferenças entre **listas** (mutáveis) e **tuplas** (imutáveis).
#   - Conjuntos (**sets**) e suas operações matemáticas.
#   - Dicionários (**dicts**) para armazenar pares *chave: valor*.
#
# ---
#
# ### 🎯 Objetivo do módulo:
# Ao final desta aula, você será capaz de:
# - Escrever seus primeiros programas em Python.
# - Declarar e manipular variáveis.
# - Trabalhar com as principais estruturas de dados.
# - Preparar-se para resolver problemas mais complexos em Engenharia Química que possam auxiliar no trabalho

# %% [markdown]
# [GitHub: **Nogfe4** 🖥️ ](github.com/nogfe4)

# %%
print("Hello World")
# Out:
# Hello World

# %%
type(1234)
# Out:
# int

# %%
type(4.7860)
# Out:
# float

# %%
type(9-71j)
# Out:
# complex

# %% [markdown]
# ## 2. Operações Matemáticas:
# ![image.png](attachment:image.png)
#
# **O separador decimal no Python é o ponto e não a vírgula. Por exemplo, o
# número *Pi* corresponde a 3.1416 e não 3,1416**

# %% [markdown]
# ---
#
#
# **Exemplo:** Calcule  a soma: $2$ + $4$ + $7$.
#
#
# ---

# %%
2+4+7
# Out:
# 13

# %% [markdown]
# ---
#
#
# **Exemplo:** Calcule  a expressão: $3.45$ - $2$. Use a função `round`  para arredondar o resultado para um número para o inteiro mais próximo (ou para um número específico de casas decimais, se você quiser).
#
#
# ---

# %%
3.45-2
round(3.45-2) 
round((3.45-2), 2)
# Out:
# 1.45

# %% [markdown]
# ---
#
#
# **Exemplo:** Calcule  a expressão: $200$ x $100$.
#
# ---

# %%
200*100
# Out:
# 20000

# %% [markdown]
# ---
#
#
# **Exemplo:** Calcule  a expressão: $44$ / $4$.
#
# ---

# %%
44/4
# Out:
# 11.0

# %% [markdown]
# ---
#
#
# **Exemplo:** Eleve o $2$ ao cubo.
#
# ---

# %%
2**3
# Out:
# 8

# %% [markdown]
# ---
#
#
# **Exemplo:** Calcule $\frac{3 × 4}{(2^2)+4/2}$
#
#
# ---

# %%
((3*4)/((2**2)+(4/2)))
# Out:
# 2.0

# %% [markdown]
# ---
#
#
# **Exemplo:** Calcule $3$ dividido por $4$, depois multiplique o resultado por $2$, depois eleve o resultado ao cubo.
#
#
# ---

# %%
3/4
# Out:
# 0.75

# %%
_*2
# Out:
# 1.5

# %%
_**3
# Out:
# 3.375

# %% [markdown]
# ## 3. Notação Científica
#
# A notação científica pode ser utilizada através da letra $e$ entre dois números. Por exemplo, $1e6 = 1,000,000$, enquanto $1e-3=0.001$.
#
# <br>
#
# ---

# %%
1e-6 + 2e-6
# Out:
# 3e-06

# %%
(3e0)*(3.65e2)*(2.4e1)*(3.6e3)
# Out:
# 94608000.0

# %%
3.3e10*(2e15)
# Out:
# 6.6e+25

# %% [markdown]
# ## 4. Módulo Math
#
# Para trabalharmos com algumas funções aritiméticas básicas como `sin`, `cos`, `tan`, `asin`, `acos`,`exp`, `log`, `log10` ou `sqrt`, é necessário importar um módulo chamado `math`.
#
# <br>
#
# ---

# %% [markdown]
# **Primeiro devemos importar o módulo usando o comando `import` e depois vamos renomear esse módulo como `mt` para que fique mais fácil de nós manipularmos as funções aritméticas.**
#
# <br>
#
# ---

# %%
import math as mt

# %% [markdown]
# ---
#
# **Exemplo:** Calcule o cosseno de $0$ usando a função `math.cos()`
#
# ---

# %%
mt.cos(0)
# Out:
# 1.0

# %% [markdown]
# ---
#
# **Exemplo:** Calcule $\ln{2}$ usando a função `math.log()`
#
# ---

# %%
mt.log(2)
# Out:
# 0.6931471805599453

# %% [markdown]
# ---
#
# **Exemplo:** Calcule $\log{100000000}$ usando a função `math.log10()`
#
# ---

# %%
mt.log10(100000000)
# Out:
# 8.0

# %% [markdown]
# ---
#
# **Exemplo:** Calcule $\sqrt{4}$ usando a função `math.sqrt()`
#
# ---

# %%
mt.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# ---
#
# **Exemplo:** Calcule $sin(\pi/2)$. Observe que `math.pi`$=\pi$
#
# ---

# %%
mt.sin(mt.pi/2)
# Out:
# 1.0

# %% [markdown]
# ---
#
# **Exemplo:** Calcule $e^{\frac{3}{4}}$ usando a função `math.exp()`.
#
# ---

# %%
mt.exp(3/4)
# Out:
# 2.117000016612675

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# a)

# %%
# b)

# %%
# c)

# %% [markdown]
# ## 4. Variáveis
#
# **O conceito de variável assume um aspecto principal no desenvolvimento de um
# programa. Variáveis permitem armazenar informações geradas no programa e
# processá-las gerando novas variáveis visando realizar a tarefa desejada pelo usuário.
# Este capítulo mostra como variáveis são criadas, manipuladas e apresentadas no
# Python, explorando seus diversos tipos, o que permite aos programas desenvolvidos
# manipular informações de diferentes origens: números inteiros, números reais, texto,
# listas de números, etc.**
#
# <br>
#
# ---

# %% [markdown]
# **Uma variável pode ser considerada como uma informação armazenada na
# memória do computador, associada a uma identificação apropriada. Uma variável é
# composta pelo nome da variável (cadeia de letras e números começando por uma letra)
# e o conteúdo (informação armazenada naquela variável, na qual para as nossas
# aplicações, vamos considerar inicialmente que esta informação é um número,
# posteriormente iremos explorar outros tipos de variáveis). Para criar o nome de uma
# variável é possível utilizar letras maiúsculas ou minúsculas, mas deve-se observar que
# o Python faz distinção entre elas, ou seja, a e A são variáveis diferentes (case sensitive).
# Uma vez que uma variável armazene um valor numérico, esta pode participar
# plenamente de operações aritméticas representando aquele valor. Por exemplo, se as
# variáveis A e B correspondem respectivamente aos valores numéricos 10 e 20, então
# digitar A + B é equivalente a digitar 10 + 20.**
# <br>
#
# ---

# %%
x = 1 
y = 2 
z = 3

# %% [markdown]
# ---
#
# **Dado as variáveis `x`, `y` e `z`, calcule:**
# 1) `x`+`y`
# 2) `z` . `y`
# 3) `x`+`y`+`z`
# 4) `x`.`y`. `z`
#
# ---

# %%
print(x+y) 
print(z**y) 
print(x+y+z) 
print(x*y*z)
# Out:
# 3
# 9
# 6
# 6

# %% [markdown]
# ---
#
# **Exemplos:**
#
# ---

# %%
#Exemplo Geral
x = 1
y = 2
z = ((x+y)**(x*y)/(x**y))
print(x+y*x)
print(x+y)
print(x**y+y**x)
print(x,y)
print(z)
# Out:
# 3
# 3
# 3
# 1 2
# 9.0

# %%
#Precedência:
a = 2 ** 10 + 5 * 3 / 2 / 4
b = (((2 ** 10)) + (((5 * 3)/ 2) / 4))
print(a)
print (b)
# Out:
# 1025.875
# 1025.875

# %%
# isso aqui é um comentário. O programa não lê 
temperatura = 10 # Celcius 
temperatura2 = temperatura + 6  
temperatura3 = temperatura + temperatura2 
temperatura4 = temperatura3*temperatura
print(temperatura)
print(temperatura2) 
print(temperatura3)
# Out:
# 10
# 16
# 26

# %%
#Trabalhando com Temperaturas 
temp_Celcius = 100 
temp_Kelvin = temp_Celcius + 273  
temp_Fah = ((9/5)*temp_Celcius) + 32 
print (temp_Celcius) 
print (temp_Kelvin)  
print (temp_Fah)
# Out:
# 100
# 373
# 212.0

# %%
#Calculando o volume:

T = 300  # [K]
P = 5    # [Bar]
R = 83.14 # [cm³·bar/(mol·K)] - Constante Universal dos Gases

V = (R*T)/P

print(f"O Volume do reator é: {V} cm³")
# Out:
# O Volume do reator é: 4988.4 cm³

# %%
#Balanço de massa simples: 

F_in = 120 # [mol/s]
X = 0.7 # conversão
F_out = F_in*(1 - X)

print(f"A vazão molar na saída é: {round(F_out,2)} mol/s")
# Out:
# A vazão molar na saída é: 36.0 mol/s

# %% [markdown]
# Os nomes das variáveis devem seguir as seguintes regras:
#
#
# *   Somente caracteres alfa-numéricos (letras e números) e *underscore* (_);
# *   Primeiro caractere deve ser uma letra ou underscore;
# *   Espaços não são permitidos;
# *   Sensível a maiúsculas e minúsculas.
#
# Exemplos:
#
#
# * ✅ Variáveis Permitidas
# `temperatura`, `pressao`, `volume_reactor`, `massa2`, `densidade_rho`, `Vfinal`, `_taxaReacao`, `camelCase`, `numeroMol`, `energia_kJ`
#
# ---------------------------------------------------------------------------
#
#
# * ❌ Variáveis Proibidas
# `2massa`, `taxa reacao`, `temperatura(ºC)`, `dens!`, `massa-total`, `ΔH`, `volume reactor`, `númeroMol`

# %% [markdown]
# Em programação, a expressão `x = y` **não** significa igualdade matemática. <br>
# Apenas significa que o valor da **direita** está sendo armazenado na variável da **esquerda** (i.e., `x ← y`).
#
# - Em **matemática**, `x = y` expressa que os valores de `x` e `y` são iguais, de forma **simétrica**.
# - Em **programação**, `=` é um **operador de atribuição**, ou seja, "pegue o valor da direita e coloque na variável da esquerda".
#
# 📌 Exemplo em Python:
# ```python
# x = 5   # o número 5 é armazenado dentro de x
# y = x   # agora y recebe o valor que está em x (y = 5)

# %%
x = 5 
x
# Out:
# 5

# %%
y = x 
y
# Out:
# 5

# %%
y = y + x + 1
y
# Out:
# 11

# %% [markdown]
# **⚠️ Importante:**
#
# * se você quiser testar igualdade lógica em Python, deve usar == (dois sinais de igual).

# %%
x = 6 

print(x == 7)
# Out:
# False

# %%
print(x == 6)
# Out:
# True

# %% [markdown]
# ## 4.1 Tipos de  Variáveis
#
# <br>
#
# ---

# %% [markdown]
# ## a) Numéricas:
# Em programação, uma **variável numérica** é um espaço de memória onde armazenamos valores que representam **números**.
# Esses números podem ser usados em **cálculos matemáticos, fórmulas e simulações**.
# <br>
#
# ---

# %%
a = 4 
b = 4.9 
c = 54j

# %% [markdown]
# ## b) Booleanas:
# **Em Python, o tipo de dado `Booleano` representa valores de verdade com dois estados possíveis: True (verdadeiro) e False (falso), sendo que a primeira letra deve ser maiúscula. Booleanos são usados em expressões condicionais, loops e operadores lógicos (and, or, not) para controlar o fluxo de execução do código, permitindo que os programas tomem decisões com base em condições.**
# <br>
#
# ---

# %%
a = 544 < 1 
print(a)
# Out:
# False

# %%
b = 150 > 12**2 
print(b)
# Out:
# True

# %%
A = True
B = False  
C = False 
D = True

# %%
A or B and C and D
# Out:
# True

# %%
C and A or D
# Out:
# True

# %% [markdown]
# ## c) Strings:
# **Em Python, uma string (tipo de dado str) é uma sequência imutável de caracteres que armazena texto, podendo incluir letras, números, símbolos e espaços. As strings são criadas utilizando aspas simples ('...') ou duplas ("...") e são fundamentais para a manipulação de dados textuais, oferecendo métodos para indexação, fatiamento, concatenação e formatação.**
# <br>
#
# ---

# %%
a = "Engenharia "
b = "Química " 
c = a + b 
d = a*3 + c 
print(d)
# Out:
# Engenharia Engenharia Engenharia Engenharia Química

# %%
A = "Hello World" 
print(A)
# Out:
# Hello World

# %%
print(len(A))
print(A[4:11])
# Out:
# 11
# o World

# %%
#Começando da 2a letra até a última 
print( A[1:len(A)])
# Out:
# ello World

# %% [markdown]
# *Função Input*
# **A função Input nos ajuda a inserir dados em nosso código para que possamos trabalhar com os mesmos**
#
# ## Exemplo
# ```python
# w = input("Dado de entrada 1: ")
# z = input("Dado de entrada 2: ")

# %% [markdown]
# *Lembrando que o input nos retorna o dado como uma *string*.*

# %%
y = input("Departamento do IQ: ")
print("O melhor departamento do IQ é:", y )

# %%
z = input("Primeira Lei da Termo: ") 
print("Qual é a expressão da Primeira Lei da Termodinâmica? Resp:", z)
# Out:
# Qual é a expressão da Primeira Lei da Termodinâmica? Resp: dU = dQ + dW

# %% [markdown]
# **🔹 O que são f-strings?**
#
# **As f-strings (formatted strings) permitem escrever textos de forma mais organizada, colocando variáveis dentro da própria string usando chaves {}.**

# %%
#Exemplo:
x = 10
print(f"O valor de x é {x}")
# Out:
# O valor de x é 10

# %% [markdown]
# 🔹**Formatando números**
#
# *Podemos usar especificadores para controlar como os números aparecem:*
#
# *:.2f → 2 casas decimais (formato de ponto flutuante).*
#
# *:.1f → 1 casa decimal.*
#
# *:.0f → arredonda para inteiro.*
#
# *:.2e → notação científica com 2 casas.*

# %%
pi = 3.14159
print(f"Pi com 2 casas = {pi:.2f}")
print(f"Pi em notação científica = {pi:.2e}")
# Out:
# Pi com 2 casas = 3.14
# Pi em notação científica = 3.14e+00

# %% [markdown]
# ## Conversões de Tipos no Python
#
# Quando usamos a função `input()`, o Python **sempre retorna uma string** (texto), mesmo que o usuário digite um número.
#
# ## Exemplo:
# ```python
# x = input("Digite um número: ")
# print(type(x))   # resultado: <class 'str'>

# %% [markdown]
# **Para poder fazer cálculos, precisamos converter essa string em um tipo numérico:**
#
# int() → converte para número inteiro.
#
# float() → converte para número real (com casas decimais)
#
# ## Exemplo:
# ```python
# a = float(input("Dado de entrada 1: "))
# b = float(input("Dado de entrada 2: "))

# %%
T = float(input("Digite a temperatura [K]: "))
P = float(input("Digite a pressão [bar]: "))
R = 83.14  

V = (R * T) / P

print(f"\n Resultados:")
print(f"Temperatura = {T:.2f} K")
print(f"Pressão = {P:.2f} bar")
print(f"Volume molar = {V:.2f} cm³/mol")

# %% [markdown]
# ## 5. Listas
#
# **O conceito de lista no Python assume um aspecto principal no desenvolvimento de um
# programa. É uma estrutura de dados que armazena uma coleção ordenada e mutável de itens, podendo conter diferentes tipos de dados (heterogênea) ou dados do mesmo tipo (homogênea), incluindo outras listas. Listas são criadas usando colchetes [], com os elementos separados por vírgulas, e os itens são acessados por índices a partir de 0, ou por índices negativos para contar do final.**
# <br>
#
# ---
